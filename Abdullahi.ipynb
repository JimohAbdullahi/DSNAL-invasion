# %%
import pandas as pd
data = [['Ayo', 10], ['Juwon' , 15], ['Abiola' , 14]]

df = pd.DataFrame (data, columns = ['Name', 'Age'])

df
# Out:
#      Name  Age
# 0     Ayo   10
# 1   Juwon   15
# 2  Abiola   14

# %%
import pandas as pd
data =[['Jimoh',10],['Fawaz',26],['Lekan',70]]
df =pd.DataFrame (data, columns = ['Name','Age',])
df
# Out:
#     Name  Age
# 0  Jimoh   10
# 1  Fawaz   26
# 2  Lekan   70

# %%
data = {'Name': ['Ayo', 'Imran' ,'Chucks' ] ,'Age':[10, 15, 14]}

df = pd.DataFrame (data)

df
# Out:
#      Name  Age
# 0     Ayo   10
# 1   Imran   15
# 2  Chucks   14

# %%
dict_data = {"State" : ["Abia", "Adamawa" , "Lagos" , "Osun", "Rivers" ],
 "Capital" : ["Umuahia" , "Yola", "Ikeja" , "Osogbo" , "Portharcourt" ],
 "area": [6320, 36917, 3345, 9251, 11077],
 "population" : [2845380 , 3178950 , 9113605 , 3416959 , 5198605 ] }

df = pd.DataFrame (dict_data )
df
# Out:
#      State       Capital   area  population
# 0     Abia       Umuahia   6320     2845380
# 1  Adamawa          Yola  36917     3178950
# 2    Lagos         Ikeja   3345     9113605
# 3     Osun        Osogbo   9251     3416959
# 4   Rivers  Portharcourt  11077     5198605

# %%
dict_data = {"First Name" : ["Abdullahi", "Suliat" , "Jimoh" ],
 "Last name" : ["Abiodun" , "olamilekan", "latifat" ],
 "Middle name" : ["Lekan" , "Latifat", "Abdulbasit" ],
 "Matric No": ['Nss/2020/005', 'Cse/2030/006', 'cht/2020/001'],}

df = pd.DataFrame (dict_data )
df
# Out:
#   First Name   Last name Middle name     Matric No
# 0  Abdullahi     Abiodun       Lekan  Nss/2020/005
# 1     Suliat  olamilekan     Latifat  Cse/2030/006
# 2      Jimoh     latifat  Abdulbasit  cht/2020/001

# %%
import pandas as pd
excel_im=pd.read_csv('desktop/data.csv')
excel_im
# Out:
#     S/N             STATE  AREA(km2)  POPULATION
# 0     0        Abia State       6320     2845380
# 1     1     Adamawa State      36917     3178950
# 2     2  Akwa Ibom State        7081     3178950
# 3     3     Anambra State       4844     4177828
# 4     4      Bauchi State      45837     4653066
# 5     5     Bayelsa State      10773     1704515
# 6     6       Benue State      34059     4253641
# 7     7       Borno State      70898     4171104
# 8     8       Cross River      20156     2892988
# 9     9       Delta State      17698     4112445
# 10   10      Ebonyi State       5670     2176947
# 11   11         Edo State      17802     3233366
# 12   12       Ekiti State       6353     2398957
# 13   13       Enugu State       7161     3267837
# 14   14               FCT       7315     1405201
# 15   15       Gombe State      18768     2365040
# 16   16         Imo State       5530     3927563
# 17   17      Jigawa State      23154     4361002
# ...
